# %%
print("hello")

# %%
# %sql
SELECT "Hello word"

# %%
# %run ./Includes/Setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
file=dbutils.fs.ls("/databricks-datasets/")
print(file)

# %%
display(file)

# %%
import time
import pandas as pd
d={'col1':[1,2],'col2':[3,4]}
df=pd.DataFrame(data=d)
x=5
time.sleep(6)
x=6
print("prefoot")
foo(df)
print("done")
display(df)
